# %% [markdown]
# # Tuple
# ## Ordered collection of items
# ## symbol()
# ## Tuple Immutable
# ## supports index

# %%
# create a tuple
students=(101,"chirag","CSE",8.9)
print(students)

# Access by index
print("Student Department:",students[2])

# Access by Negative index
print("Accessing by negative index:",students[-2])
# Out:
# (101, 'chirag', 'CSE', 8.9)
# Student Department: CSE
# Accessing by negative index: CSE

# %%
subjects=("DSV", "Machine Learning","OS","Cloud","SQL","Statistics","Python")
print(subjects)
# find the length of the tuple
print("Length of the Tuple:",len(subjects))
# Out:
# ('DSV', 'Machine Learning', 'OS', 'Cloud', 'SQL', 'Statistics', 'Python')
# Length of the Tuple: 7

# %%
# Tuple Slicing
print(subjects[3:])
print(subjects[1:5])
# Out:
# ('Cloud', 'SQL', 'Statistics', 'Python')
# ('Machine Learning', 'OS', 'Cloud', 'SQL')

# %%
# tuple is mutable or immutable
print(students)
students[1]="Manish"
print(students)
# Out:
# (101, 'chirag', 'CSE', 8.9)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1599/2298224857.py in <cell line: 0>()
#       1 # tuple is mutable or immutable
#       2 print(students)
# ----> 3 students[1]="Manish"
#       4 print(students)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Nested tuple
student_info=(1005,"Rahul",(89,98,78,75))
print(student_info)
print("Nested tuple displaying 3rd subject mark:",student_info[2][2])
# Out:
# (1005, 'Rahul', (89, 98, 78, 75))
# Nested tuple displaying 3rd subject mark: 78

# %%
position=student_info.index("Rahul")
print("Data Rahul Present in the index:",position)
# Out:
# Data Rahul Present in the index: 1

# %% [markdown]
# # SET
# ## unordered collection of items
# ## mutable
# ## symbol {}
# ## No Duplication
# ## it will give the unique values
# ## union, intersection, Difference, Symmetric difference, superset

# %%
#create a set
subjects_info={"Data Science and Visualization",
               "SQL",
               "Statistics",
               "Machine Learning"}
print(subjects_info)
# Out:
# {'SQL', 'Statistics', 'Machine Learning', 'Data Science and Visualization'}

# %%
studentsname={"Amit", "Sanjiv", "kalai", "Amit", "Kiran", "Neha", "Sanjiv"}
print(studentsname)
# Out:
# {'Kiran', 'Sanjiv', 'Neha', 'Amit', 'kalai'}

# %%
print(studentsname[2])

# %%
# Adding an element in the set
studentsname.add("Priya")
print(studentsname)

# update the set
studentsname.update(["Anil", "Nandhini", "Balaji"])
print(studentsname)
# Out:
# {'Kiran', 'Sanjiv', 'Neha', 'Amit', 'Priya', 'kalai'}
# {'Sanjiv', 'Kiran', 'Anil', 'Amit', 'Priya', 'Balaji', 'Nandhini', 'Neha', 'kalai'}

# %%
# Remove an item in the set
# studentsname.remove("Amit")
# print(studentsname)

# remove an item
# studentsname.remove("Amit")k

# Students
studentsname.discard("Priya")
print(studentsname)

studentsname.discard("Amit")
print(studentsname)
# Out:
# {'Sanjiv', 'Kiran', 'Anil', 'Amit', 'Balaji', 'Nandhini', 'Neha', 'kalai'}
# {'Sanjiv', 'Kiran', 'Anil', 'Balaji', 'Nandhini', 'Neha', 'kalai'}

# %%
# clear and delete
numbers={89,78,68,97,69}
numbers.clear()
print(numbers)


del numbers
print(numbers)
# Out:
# set()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1599/3448160984.py in <cell line: 0>()
#       6
#       7 del numbers
# ----> 8 print(numbers)
#
# NameError: name 'numbers' is not defined

# %%
#  find the element in the set
print(studentsname)

# find the elements Anil
print("Anil" in studentsname)
# Out:
# {'Sanjiv', 'Kiran', 'Anil', 'Balaji', 'Nandhini', 'Neha', 'kalai'}
# True

# %%
# set operations
# Union
# Intersection
# difference
# Symetric difference


python_students={"rahul", "Priya", "Hari", "Ganesh"}
java_students={"rahul","Hari","Kiran", "Ravi","Giri"}

res_union=python_students.union(java_students)
print(res_union)
# Out:
# {'rahul', 'Priya', 'Ganesh', 'Giri', 'Hari', 'Kiran', 'Ravi'}

# %%
res_inter=python_students.intersection(java_students)
print(res_inter)
# Out:
# {'Hari', 'rahul'}

# %%
res_diff=python_students.difference(java_students)
print(res_diff)
# Out:
# {'Priya', 'Ganesh'}

# %%
my_list = [101,102,103,106,103,102]
unique_element =set(my_list)
print(unique_element)
#u_r_no=list(unique_element)
#print(u_r_no)
# Out:
# {106, 101, 102, 103}

# %%
unique_element_list = list(unique_element)
print(unique_element_list)
# Out:
# [106, 101, 102, 103]
